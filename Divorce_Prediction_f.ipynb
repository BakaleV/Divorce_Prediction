# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('divorce.csv')
raw_data.head()
# Out:
#    Sorry_end  Ignore_diff  begin_correct  Contact  Special_time  No_home_time  \
# 0          2            2              4        1             0             0
# 1          4            4              4        4             4             0
# 2          2            2              2        2             1             3
# 3          3            2              3        2             3             3
# 4          2            2              1        1             1             1
#
#    2_strangers  enjoy_holiday  enjoy_travel  common_goals  ...  \
# 0            0              0             0             0  ...
# 1            0              4             4             4  ...
# 2            2              1             1             2  ...
# 3            3              3             3             3  ...
# 4            0              0             0             0  ...
#
#    silence_for_harm  silence_fear_anger  I'm_right  accusations  \
# ...

# %%
raw_data.describe(include='all')
# Out:
#         Sorry_end  Ignore_diff  begin_correct     Contact  Special_time  \
# count  170.000000   170.000000     170.000000  170.000000    170.000000
# mean     1.776471     1.652941       1.764706    1.482353      1.541176
# std      1.627257     1.468654       1.415444    1.504327      1.632169
# min      0.000000     0.000000       0.000000    0.000000      0.000000
# 25%      0.000000     0.000000       0.000000    0.000000      0.000000
# 50%      2.000000     2.000000       2.000000    1.000000      1.000000
# 75%      3.000000     3.000000       3.000000    3.000000      3.000000
# max      4.000000     4.000000       4.000000    4.000000      4.000000
#
#        No_home_time  2_strangers  enjoy_holiday  enjoy_travel  common_goals  \
# count    170.000000   170.000000     170.000000    170.000000    170.000000
# mean       0.747059     0.494118       1.452941      1.458824      1.576471
# std        0.904046     0.898698       1.546371      1.557976      1.421529
# ...

# %%
raw_data.isnull().sum()
# Out:
# Sorry_end                        0
# Ignore_diff                      0
# begin_correct                    0
# Contact                          0
# Special_time                     0
# No_home_time                     0
# 2_strangers                      0
# enjoy_holiday                    0
# enjoy_travel                     0
# common_goals                     0
# harmony                          0
# freeom_value                     0
# entertain                        0
# people_goals                     0
# dreams                           0
# love                             0
# happy                            0
# marriage                         0
# roles                            0
# trust                            0
# likes                            0
# care_sick                        0
# fav_food                         0
# stresses                         0
# inner_world                      0
# anxieties                        0
# current_stress                   0
# ...

# %%
plt.figure(figsize=(16,9))
x = raw_data.drop(['incompetence'],axis = 1)
ax = sns.heatmap(x.corr(),annot = True,cmap = 'viridis')
plt.show()

# %%
sns.displot(raw_data['Sorry_end'])              
sns.displot(raw_data['Ignore_diff'])
sns.displot(raw_data['begin_correct'])
sns.displot(raw_data['Contact'])
sns.displot(raw_data['Special_time'])
sns.displot(raw_data['No_home_time'])
sns.displot(raw_data['2_strangers'])
sns.displot(raw_data['enjoy_holiday'])
sns.displot(raw_data['enjoy_travel'])
sns.displot(raw_data['common_goals'])
sns.displot(raw_data['harmony'])

# %%
sns.displot(raw_data['freeom_value'])
sns.displot(raw_data['entertain'])
sns.displot(raw_data['people_goals'])
sns.displot(raw_data['dreams'])
sns.displot(raw_data['love'])
sns.displot(raw_data['happy'])
sns.displot(raw_data['marriage'])
sns.displot(raw_data['roles'])
sns.displot(raw_data['trust'])
sns.displot(raw_data['likes'])
sns.displot(raw_data['care_sick'])

# %%
sns.displot(raw_data['fav_food'])
sns.displot(raw_data['stresses'])
sns.displot(raw_data['inner_world'])
sns.displot(raw_data['anxieties'])
sns.displot(raw_data['current_stress'])
sns.displot(raw_data['hopes_wishes'])
sns.displot(raw_data['know_well'])
sns.displot(raw_data['friends_social'])
sns.displot(raw_data['Aggro_argue'])
sns.displot(raw_data['Always_never'])
sns.displot(raw_data['negative_personality'])

# %%
sns.displot(raw_data['offensive_expressions'])
sns.displot(raw_data['insult'])
sns.displot(raw_data['humiliate'])
sns.displot(raw_data['not_calm'])
sns.displot(raw_data['hate_subjects'])
sns.displot(raw_data['sudden_discussion'])
sns.displot(raw_data['idk_what\'s_going_on'])
sns.displot(raw_data['calm_breaks'])
sns.displot(raw_data['argue_then_leave'])
sns.displot(raw_data['silent_for_calm'])
sns.displot(raw_data['good_to_leave_home'])

# %%
sns.displot(raw_data['silence_instead_of_discussion'])
sns.displot(raw_data['silence_for_harm'])
sns.displot(raw_data['silence_fear_anger'])
sns.displot(raw_data['I\'m_right'])
sns.displot(raw_data['accusations'])
sns.displot(raw_data['I\'m_not_guilty'])
sns.displot(raw_data['I\'m_not_wrong'])
sns.displot(raw_data['no_hesitancy_inadequate'])
sns.displot(raw_data['you\'re_inadequate'])
sns.displot(raw_data['incompetence'])
sns.displot(raw_data['Divorce_Y_N'])

# %%
data = raw_data.reset_index(drop = True)
data.head()
# Out:
#    Sorry_end  Ignore_diff  begin_correct  Contact  Special_time  No_home_time  \
# 0          2            2              4        1             0             0
# 1          4            4              4        4             4             0
# 2          2            2              2        2             1             3
# 3          3            2              3        2             3             3
# 4          2            2              1        1             1             1
#
#    2_strangers  enjoy_holiday  enjoy_travel  common_goals  ...  \
# 0            0              0             0             0  ...
# 1            0              4             4             4  ...
# 2            2              1             1             2  ...
# 3            3              3             3             3  ...
# 4            0              0             0             0  ...
#
#    silence_for_harm  silence_fear_anger  I'm_right  accusations  \
# ...

# %%
targets = data['Divorce_Y_N']
inputs = data.drop(['Divorce_Y_N'],axis = 1)
inputs.head()
# Out:
#    Sorry_end  Ignore_diff  begin_correct  Contact  Special_time  No_home_time  \
# 0          2            2              4        1             0             0
# 1          4            4              4        4             4             0
# 2          2            2              2        2             1             3
# 3          3            2              3        2             3             3
# 4          2            2              1        1             1             1
#
#    2_strangers  enjoy_holiday  enjoy_travel  common_goals  ...  \
# 0            0              0             0             0  ...
# 1            0              4             4             4  ...
# 2            2              1             1             2  ...
# 3            3              3             3             3  ...
# 4            0              0             0             0  ...
#
#    silence_instead_of_discussion  silence_for_harm  silence_fear_anger  \
# ...

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(inputs,targets,test_size = 0.2,random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier


KNC = KNeighborsClassifier(n_neighbors=3)
KNC.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predictor = KNC.predict(x_test)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_predictor)
# Out:
# array([[14,  0],
#        [ 1, 19]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predictor))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.97        34
#    macro avg       0.97      0.97      0.97        34
# weighted avg       0.97      0.97      0.97        34

# %%
#split the dataset into train, validation, and test
sample_count = inputs.shape[0]
train_count = int(0.8*sample_count)
validation_count = int(0.1*sample_count)
test_count = int(sample_count - validation_count - train_count)
print(sample_count,train_count,validation_count,test_count)
# Out:
# 170 136 17 17

# %%
train_inputs = inputs[:train_count]
validation_inputs = inputs[train_count:validation_count + train_count]
test_inputs = inputs[validation_count + train_count :]

train_targets = targets[:train_count]
validation_targets = targets[train_count:validation_count + train_count]
test_targets = targets[validation_count + train_count :]

# %%
#save the data in .npz files
np.savez('Divorce_data_train',inputs = train_inputs,targets = train_targets)
np.savez('Divorce_data_validation',inputs = validation_inputs,targets = validation_targets)
np.savez('Divorce_data_test',inputs = test_inputs,targets = test_targets)
